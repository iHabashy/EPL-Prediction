# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
import numpy as np

# %%
epl_modified_stats = pd.read_csv('england-premier-league-league-2015-to-2022-stats.csv')
epl_modified_teams = pd.read_csv('england-premier-league-league-2015-to-2022-teams.csv')
epl_modified_teams2 = pd.read_csv('england-premier-league-league-2015-to-2022-teams2.csv')
epl_2022_stats = pd.read_csv('england-premier-league-teams-2021-to-2022-stats.csv')

# %%
epl_modified_stats.head()
# Out:
#              name     season     status  attendance  number_of_clubs  \
# 0  Premier League  2015/2016  Completed       43250               20
# 1  Premier League  2016/2017  Completed       41024               20
# 2  Premier League  2017/2018  Completed       45849               20
# 3  Premier League  2018/2019  Completed       44060               20
# 4  Premier League  2019/2020  Completed       39050               20
#
#    total_matches  matches_completed  game_week  total_game_week  progress  \
# 0            380                380         38               38       100
# 1            380                380         38               38       100
# 2            380                380         38               38       100
# 3            380                380         38               38       100
# 4            380                380         38               38       100
#
#    ...  goals_min_61_to_70  goals_min_71_to_80  goals_min_81_to_90  \
# 0  ...                 128                 104                 173
# 1  ...                 114                 119                 191
# 2  ...                 124                 123                 171
# 3  ...                 133                 119                 186
# 4  ...                 100                 120                 169
#
#    goals_min_0_to_15  goals_min_16_to_30  goals_min_31_to_45  \
# 0                117                 154                 186
# 1                132                 134                 196
# 2                119                 148                 160
# 3                134                 172                 170
# 4                115                 158                 202
#
#    goals_min_46_to_60  goals_min_61_to_75  goals_min_76_to_90  \
# 0                 164                 177                 228
# 1                 178                 176                 248
# 2                 173                 190                 228
# 3                 158                 185                 253
# 4                 170                 166                 223
#
#    xg_avg_per_match
# 0              0.00
# 1              3.26
# 2              2.91
# 3              2.80
# 4              3.11
#
# [5 rows x 71 columns]

# %%
epl_modified_stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 71 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   name                                 7 non-null      object
#  1   season                               7 non-null      object
#  2   status                               7 non-null      object
#  3   attendance                           7 non-null      int64
#  4   number_of_clubs                      7 non-null      int64
#  5   total_matches                        7 non-null      int64
#  6   matches_completed                    7 non-null      int64
#  7   game_week                            7 non-null      int64
#  8   total_game_week                      7 non-null      int64
#  9   progress                             7 non-null      int64
#  10  average_goals_per_match              7 non-null      float64
#  11  average_scored_home_team             7 non-null      float64
#  12  average_scored_away_team             7 non-null      float64
#  13  btts_percentage                      7 non-null      int64
#  14  clean_sheets_percentage              7 non-null      int64
#  15  prediction_risk                      7 non-null      int64
#  16  home_scored_advantage_percentage     7 non-null      int64
#  17  home_defence_advantage_percentage    7 non-null      int64
#  18  home_advantage_percentage            7 non-null      int64
#  19  average_corners_per_match            7 non-null      float64
#  20  average_corners_per_match_home_team  7 non-null      float64
#  21  average_corners_per_match_away_team  7 non-null      float64
#  22  total_corners_for_season             7 non-null      int64
#  23  average_cards_per_match              7 non-null      float64
#  24  average_cards_per_match_home_team    7 non-null      float64
#  25  average_cards_per_match_away_team    7 non-null      float64
#  26  total_cards_for_season               7 non-null      int64
#  27  over_05_percentage                   7 non-null      int64
#  28  over_15_percentage                   7 non-null      int64
#  29  over_25_percentage                   7 non-null      int64
#  30  over_35_percentage                   7 non-null      int64
#  31  over_45_percentage                   7 non-null      int64
#  32  over_55_percentage                   7 non-null      int64
#  33  under_05_percentage                  7 non-null      int64
#  34  under_15_percentage                  7 non-null      int64
#  35  under_25_percentage                  7 non-null      int64
#  36  under_35_percentage                  7 non-null      int64
#  37  under_45_percentage                  7 non-null      int64
#  38  under_55_percentage                  7 non-null      int64
#  39  over_65_corners_percentage           7 non-null      int64
#  40  over_75_corners_percentage           7 non-null      int64
#  41  over_85_corners_percentage           7 non-null      int64
#  42  over_95_corners_percentage           7 non-null      int64
#  43  over_105_corners_percentage          7 non-null      int64
#  44  over_115_corners_percentage          7 non-null      int64
#  45  over_125_corners_percentage          7 non-null      int64
#  46  over_135_corners_percentage          7 non-null      int64
#  47  over_05_cards_percentage             7 non-null      int64
#  48  over_15_cards_percentage             7 non-null      int64
#  49  over_25_cards_percentage             7 non-null      int64
#  50  over_35_cards_percentage             7 non-null      int64
#  51  over_45_cards_percentage             7 non-null      int64
#  52  over_55_cards_percentage             7 non-null      int64
#  53  over_65_cards_percentage             7 non-null      int64
#  54  over_75_cards_percentage             7 non-null      int64
#  55  goals_min_0_to_10                    7 non-null      int64
#  56  goals_min_11_to_20                   7 non-null      int64
#  57  goals_min_21_to_30                   7 non-null      int64
#  58  goals_min_31_to_40                   7 non-null      int64
#  59  goals_min_41_to_50                   7 non-null      int64
#  60  goals_min_51_to_60                   7 non-null      int64
#  61  goals_min_61_to_70                   7 non-null      int64
#  62  goals_min_71_to_80                   7 non-null      int64
#  63  goals_min_81_to_90                   7 non-null      int64
#  64  goals_min_0_to_15                    7 non-null      int64
#  65  goals_min_16_to_30                   7 non-null      int64
#  66  goals_min_31_to_45                   7 non-null      int64
#  67  goals_min_46_to_60                   7 non-null      int64
#  68  goals_min_61_to_75                   7 non-null      int64
#  69  goals_min_76_to_90                   7 non-null      int64
#  70  xg_avg_per_match                     7 non-null      float64
# dtypes: float64(10), int64(58), object(3)
# memory usage: 4.0+ KB

# %% [markdown]
# ---

# %%
## Effect of COVID on match score

# %%
plt.figure(figsize=(10,4))


sns.barplot(data=epl_modified_stats, x='average_scored_home_team', y='season')

# %%
plt.figure(figsize=(10,4))

sns.barplot(data=epl_modified_stats, x='average_scored_away_team', y='season')

# %% [markdown]
# ---

# %%
epl_modified_teams.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140 entries, 0 to 139
# Columns: 293 entries, team_name to over145_corners_percentage
# dtypes: float64(36), int64(253), object(4)
# memory usage: 320.6+ KB

# %%
epl_modified_teams.head()
# Out:
#     team_name common_name     season  country  matches_played  \
# 0  Arsenal FC     Arsenal  2015/2016  England              38
# 1  Arsenal FC     Arsenal  2016/2017  England              38
# 2  Arsenal FC     Arsenal  2017/2018  England              38
# 3  Arsenal FC     Arsenal  2018/2019  England              38
# 4  Arsenal FC     Arsenal  2019/2020  England              38
#
#    matches_played_home  matches_played_away  suspended_matches  wins  \
# 0                   19                   19                  0    20
# 1                   19                   19                  0    23
# 2                   19                   19                  0    19
# 3                   19                   19                  0    21
# 4                   19                   19                  0    14
#
#    wins_home  ...  goals_conceded_min_61_to_70  goals_conceded_min_71_to_80  \
# 0         12  ...                            3                            1
# 1         14  ...                            7                            3
# 2         15  ...                            7                            8
# 3         14  ...                           12                            1
# 4         10  ...                            2                            5
#
#    goals_conceded_min_81_to_90  draw_percentage_overall  draw_percentage_home  \
# 0                            6                       29                    21
# 1                            5                       16                    16
# 2                            8                       16                    11
# 3                            8                       18                    16
# 4                            9                       37                    32
#
#    draw_percentage_away  loss_percentage_ovearll  loss_percentage_home  \
# 0                    37                       18                    16
# 1                    16                       24                    11
# 2                    21                       34                    11
# 3                    21                       26                    11
# 4                    42                       26                    16
#
#    loss_percentage_away  over145_corners_percentage
# 0                    21                           8
# 1                    37                           8
# 2                    58                          11
# 3                    42                           5
# 4                    37                          34
#
# [5 rows x 293 columns]

# %%
epl_modified_teams2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140 entries, 0 to 139
# Columns: 442 entries, team_name to failed_to_score_2h_away
# dtypes: float64(42), int64(396), object(4)
# memory usage: 483.6+ KB

# %%
epl_modified_teams2.head()
# Out:
#     team_name common_name     season  country  average_attendance_overall  \
# 0  Arsenal FC     Arsenal  2015/2016  England                       47407
# 1  Arsenal FC     Arsenal  2016/2017  England                       47142
# 2  Arsenal FC     Arsenal  2017/2018  England                       48852
# 3  Arsenal FC     Arsenal  2018/2019  England                       49412
# 4  Arsenal FC     Arsenal  2019/2020  England                       36482
#
#    average_attendance_home  average_attendance_away  \
# 0                    59941                    35533
# 1                    59952                    35005
# 2                    59323                    38381
# 3                    59899                    38925
# 4                    47589                    25376
#
#    minutes_per_goal_scored_overall  minutes_per_goal_scored_home  \
# 0                               53                            55
# 1                               44                            44
# 2                               46                            32
# 3                               47                            41
# 4                               61                            48
#
#    minutes_per_goal_scored_away  ...  btts_2h_away  \
# 0                            50  ...             6
# 1                            45  ...             9
# 2                            86  ...             7
# 3                            55  ...             6
# 4                            86  ...             3
#
#    btts_2h_percentage_overall  btts_2h_percentage_home  \
# 0                          16                        0
# 1                          34                       21
# 2                          37                       37
# 3                          28                       26
# 4                          16                       16
#
#    btts_2h_percentage_away  clean_sheets_2h_overall  clean_sheets_2h_home  \
# 0                       32                       26                    15
# 1                       47                       18                    14
# 2                       37                       17                    11
# 3                       32                       18                    12
# 4                       16                       21                    10
#
#    clean_sheets_2h_away  failed_to_score_2h_overall  failed_to_score_2h_home  \
# 0                    11                          19                       10
# 1                     4                          10                        3
# 2                     6                          14                        4
# 3                     6                          14                        4
# 4                    11                          19                       10
#
#    failed_to_score_2h_away
# 0                        9
# 1                        7
# 2                       10
# 3                       10
# 4                        9
#
# [5 rows x 442 columns]

# %%
## Win Percentage and Leading at half time

# %%
plt.figure(figsize=(12,8))
sns.lineplot(y='win_percentage',x='leading_at_half_time',data=epl_modified_teams)

# %% [markdown]
# ---

# %%
# Total shots, Goals scored

# %%
epl_2022_stats.head()
# Out:
#               team_name        common_name     season  country  \
# 0            Arsenal FC            Arsenal  2021/2022  England
# 1  Tottenham Hotspur FC  Tottenham Hotspur  2021/2022  England
# 2    Manchester City FC    Manchester City  2021/2022  England
# 3     Leicester City FC     Leicester City  2021/2022  England
# 4     Crystal Palace FC     Crystal Palace  2021/2022  England
#
#    matches_played  matches_played_home  matches_played_away  \
# 0              18                    9                    9
# 1              14                    8                    6
# 2              17                    9                    8
# 3              16                    8                    8
# 4              17                    9                    8
#
#    suspended_matches  wins  wins_home  ...  goals_conceded_min_61_to_70  \
# 0                  1    10          7  ...                            1
# 1                  3     8          6  ...                            2
# 2                  0    13          7  ...                            0
# 3                  2     6          4  ...                            3
# 4                  1     4          3  ...                            3
#
#    goals_conceded_min_71_to_80  goals_conceded_min_81_to_90  \
# 0                            7                            3
# 1                            2                            5
# 2                            2                            3
# 3                            3                            2
# 4                            2                            5
#
#    draw_percentage_overall  draw_percentage_home  draw_percentage_away  \
# 0                       11                    11                    11
# 1                        7                     0                    17
# 2                       12                    11                    13
# 3                       25                    13                    38
# 4                       47                    56                    38
#
#    loss_percentage_ovearll  loss_percentage_home  loss_percentage_away  \
# 0                       33                    11                    56
# 1                       36                    25                    50
# 2                       12                    11                    13
# 3                       38                    38                    38
# 4                       29                    11                    50
#
#    over145_corners_percentage
# 0                          12
# 1                          14
# 2                          18
# 3                          13
# 4                          12
#
# [5 rows x 293 columns]

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(data= epl_2022_stats, x="shots", y="goals_scored",hue='team_name')

# %% [markdown]
# ---

# %%
epl_2022_stats['goals_shots_ratio'] = epl_2022_stats['goals_scored'] / epl_2022_stats['shots'] *100

plt.figure(figsize=(20,8))
sns.barplot(data=epl_2022_stats, x='team_name', y='goals_shots_ratio')
